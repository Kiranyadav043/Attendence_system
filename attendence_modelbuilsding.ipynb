# %%
import numpy as np
import pandas as pd
import sklearn
import optuna
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split,cross_validate
from sklearn.ensemble import RandomForestClassifier



data = pd.read_csv(r"D:\amareshsirnotes\attendence_data.csv")
data.dropna(inplace=True)
x = data.iloc[:,:-1]
y = data.iloc[:,-1]
x_final = []

# preprocessing
for i in x.values:
    landmarks = i.reshape(478,3)
    centre = landmarks-landmarks[0]
    distance = np.linalg.norm(landmarks[33]-landmarks[263])
    normalize = centre/distance
    x_final.append(normalize.flatten())
    
x_f = pd.DataFrame(x_final)
x_f.dropna(inplace=True)
# train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_final,y,test_size=0.2,stratify=y,random_state=12)

# Label encoding
le = LabelEncoder()
y_train_final = le.fit_transform(y_train)
y_test_final = le.transform(y_test)

# Model 
def objective(trial):
    clf = RandomForestClassifier(
                n_estimators=trial.suggest_int("n_estimators", 50, 300),
                max_depth=trial.suggest_int("max_depth", 5, 30),
                min_samples_split=trial.suggest_int("min_samples_split", 2, 10),
                min_samples_leaf=trial.suggest_int("min_samples_leaf", 1, 5),
            )
    scores = cross_validate(clf, x_train, y_train_final, cv=3, scoring='accuracy')
    return scores['test_score'].mean()

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)

print("Best parameters:", study.best_params)
# Out:
# [I 2025-07-15 10:52:23,108] A new study created in memory with name: no-name-91da8be6-a0f0-429e-b154-d27a9b78bfd0
# [I 2025-07-15 10:52:49,742] Trial 0 finished with value: 0.9574212518978341 and parameters: {'n_estimators': 175, 'max_depth': 23, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.9574212518978341.
# [I 2025-07-15 10:53:14,841] Trial 1 finished with value: 0.9507821501556247 and parameters: {'n_estimators': 180, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.9574212518978341.
# [I 2025-07-15 10:53:22,055] Trial 2 finished with value: 0.942577192312937 and parameters: {'n_estimators': 55, 'max_depth': 23, 'min_samples_split': 10, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.9574212518978341.
# [I 2025-07-15 10:53:50,008] Trial 3 finished with value: 0.951561417525325 and parameters: {'n_estimators': 205, 'max_depth': 26, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.9574212518978341.
# [I 2025-07-15 10:54:03,238] Trial 4 finished with value: 0.9582032647779385 and parameters: {'n_estimators': 89, 'max_depth': 22, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 4 with value: 0.9582032647779385.
# [I 2025-07-15 10:54:29,433] Trial 5 finished with value: 0.9441403029030111 and parameters: {'n_estimators': 205, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 5}. Best is trial 4 with value: 0.9582032647779385.
# [I 2025-07-15 10:54:53,320] Trial 6 finished with value: 0.9503904573379715 and parameters: {'n_estimators': 165, 'max_depth': 28, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 4 with value: 0.9582032647779385.
# [I 2025-07-15 10:55:40,420] Trial 7 finished with value: 0.9449218581980482 and parameters: {'n_estimators': 238, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 5}. Best is trial 4 with value: 0.9582032647779385.
# [I 2025-07-15 10:57:16,632] Trial 8 finished with value: 0.955469651585578 and parameters: {'n_estimators': 299, 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 4 with value: 0.9582032647779385.
# [I 2025-07-15 10:58:12,857] Trial 9 finished with value: 0.9269511198479354 and parameters: {'n_estimators': 227, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 4 with value: 0.9582032647779385.
# [I 2025-07-15 10:58:34,475] Trial 10 finished with value: 0.9585935848403898 and parameters: {'n_estimators': 70, 'max_depth': 16, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 10 with value: 0.9585935848403898.
# [I 2025-07-15 10:58:55,510] Trial 11 finished with value: 0.9613294859580871 and parameters: {'n_estimators': 66, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 10:59:30,893] Trial 12 finished with value: 0.953125443285534 and parameters: {'n_estimators': 111, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 10:59:48,814] Trial 13 finished with value: 0.9558599716480293 and parameters: {'n_estimators': 55, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:00:28,083] Trial 14 finished with value: 0.9546867235353388 and parameters: {'n_estimators': 125, 'max_depth': 18, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:00:57,135] Trial 15 finished with value: 0.9570304742503155 and parameters: {'n_estimators': 92, 'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:01:36,551] Trial 16 finished with value: 0.9585931272553223 and parameters: {'n_estimators': 130, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:02:02,753] Trial 17 finished with value: 0.9582023496078037 and parameters: {'n_estimators': 83, 'max_depth': 20, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:02:47,311] Trial 18 finished with value: 0.9578134023005548 and parameters: {'n_estimators': 145, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:03:08,942] Trial 19 finished with value: 0.9558595140629619 and parameters: {'n_estimators': 72, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:03:31,013] Trial 20 finished with value: 0.8945307602409827 and parameters: {'n_estimators': 105, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:04:11,146] Trial 21 finished with value: 0.9570318470055176 and parameters: {'n_estimators': 133, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:04:27,244] Trial 22 finished with value: 0.955469651585578 and parameters: {'n_estimators': 53, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:05:03,221] Trial 23 finished with value: 0.9597677481232149 and parameters: {'n_estimators': 115, 'max_depth': 17, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:05:30,683] Trial 24 finished with value: 0.9566406117729316 and parameters: {'n_estimators': 77, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:06:09,162] Trial 25 finished with value: 0.9593751401354269 and parameters: {'n_estimators': 109, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:06:47,192] Trial 26 finished with value: 0.95781248713042 and parameters: {'n_estimators': 108, 'max_depth': 21, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:07:36,230] Trial 27 finished with value: 0.9496093596280016 and parameters: {'n_estimators': 150, 'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:08:07,192] Trial 28 finished with value: 0.9578115719602852 and parameters: {'n_estimators': 101, 'max_depth': 26, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.9613294859580871.
# [I 2025-07-15 11:08:44,717] Trial 29 finished with value: 0.9582032647779385 and parameters: {'n_estimators': 118, 'max_depth': 25, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.9613294859580871.
# Best parameters: {'n_estimators': 66, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1}

# %%
model = RandomForestClassifier(**study.best_params,random_state=42)

# %%
model.fit(x_train,y_train_final)
# Out:
# RandomForestClassifier(max_depth=15, n_estimators=66, random_state=42)

# %%
pred_ytest = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(pred_ytest,y_test_final)
# Out:
# 0.9609375
